# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriarkamal-dsi/LearnTensorflow/blob/master/firstOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bismillahir rahmanir rahim, Thanks Allah 4 everything

# %% [markdown]
# first coding in tensorflow and colab

# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3799
# Epoch 2/500
# 1/1 [==============================] - 0s 913us/step - loss: 1.2201
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0917
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9879
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9036
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8347
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7779
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7308
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6912
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6578
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6291
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6042
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.986258]]
